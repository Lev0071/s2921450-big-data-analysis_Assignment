# %%
import numpy as np
import pandas as pd
import nltk
import string
import random
import copy

# %%
df = pd.read_csv('data.csv', low_memory=False)
df = df.sample(len(df)//32,random_state=0)
df = df.reset_index(drop=True)

# %%
df.describe()
# Out:
#        LowestSalary  HighestSalary
# count   9952.000000    9952.000000
# mean      65.574759     115.072347
# std       50.966453     180.476991
# min        0.000000      30.000000
# 25%       30.000000      40.000000
# 50%       60.000000      70.000000
# 75%      100.000000     120.000000
# max      200.000000     999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9952 entries, 0 to 9951
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 9952 non-null   object
#  1   Title              9952 non-null   object
#  2   Company            9576 non-null   object
#  3   Date               9952 non-null   object
#  4   Location           6204 non-null   object
#  5   Area               3894 non-null   object
#  6   Classification     6204 non-null   object
#  7   SubClassification  6204 non-null   object
#  8   Requirement        9952 non-null   object
#  9   FullDescription    9420 non-null   object
#  10  LowestSalary       9952 non-null   int64
#  11  HighestSalary      9952 non-null   int64
#  12  JobType            9421 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 1010.9+ KB

# %%
df.head(10)
# Out:
#                                                   Id  \
# 0                                           37515643
# 1                                           38154814
# 2                                           37999957
# 3  37936799&searchrequesttoken=57f67ab1-3cfd-4254...
# 4                                           37680645
# 5                                           38063057
# 6                                           38079997
# 7                                           38068325
# 8                                           37409088
# 9                                           37449308
#
#                                                Title  \
# 0  Forklift Drivers WANTED! ***FULL TIME OPPORTUN...
# 1                    Delivery Lead/Iteration Manager
# 2  Local Manager. Permanent, Full time - Lower Hu...
# 3            Clinical Nurse Educator - Youth Justice
# 4                          Graduate Project Engineer
# 5                                       Receptionist
# 6             Principal Engineer Operations Planning
# 7           Forklift Operator with Admin Experience
# 8    Retail Goods Receiving / Warehouse - Springwood
# 9         Commercial Manager - Oil & Gas - PNG based
#
#                                    Company                      Date  \
# 0           Australian Personnel Solutions  2018-10-19T00:00:00.000Z
# 1                   DIUS Computing Pty Ltd  2019-01-20T00:00:00.000Z
# 2                    Life Without Barriers  2019-01-02T00:00:00.000Z
# 3                 Correct Care Australasia  2018-12-14T00:00:00.000Z
# 4                                      NaN  2018-11-09T00:00:00.000Z
# 5  Gough Property & Real Estate Recruiters  2019-01-09T00:00:00.000Z
# 6                                Powerlink  2019-01-10T00:00:00.000Z
# 7                                     Toll  2019-01-10T00:00:00.000Z
# 8              Total Tools - Store Network  2018-10-08T00:00:00.000Z
# 9                                    Amida  2018-10-12T00:00:00.000Z
#
#     Location                      Area                        Classification  \
# 0  Melbourne           Western Suburbs  Manufacturing, Transport & Logistics
# 1        NaN                       NaN                                   NaN
# 2        NaN                       NaN                                   NaN
# 3  Melbourne       CBD & Inner Suburbs                  Healthcare & Medical
# 4  Melbourne           Western Suburbs                           Engineering
# 5        NaN                       NaN                                   NaN
# 6        NaN                       NaN                                   NaN
# 7        NaN                       NaN                                   NaN
# 8   Brisbane  Southern Suburbs & Logan            Retail & Consumer Products
# 9   Brisbane                       NaN            Mining, Resources & Energy
#
#                                  SubClassification  \
# 0              Warehousing, Storage & Distribution
# 1                                              NaN
# 2                                              NaN
# 3  Nursing - Psych, Forensic & Correctional Health
# 4                              Project Engineering
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                            Other
# 9                                       Management
#
#                                          Requirement  \
# 0  Our client is looking for an experienced count...
# 1  If you love all things Agile and have experien...
# 2  Join our Lower Hunter team as a Local Manager ...
# 3  This is an exciting opportunity for a Clinical...
# 4  Elastomers Australia are currently seeking a G...
# 5  ** Entry Level Real Estate Reception roles SYD...
# 6  Critical expert role to keep Queensland's HV t...
# 7  Immediate start / Morning shift available / Ex...
# 8  Utilise your goods receiving experience and wa...
# 9  Exciting opportunity to work with a reputable ...
#
#                                      FullDescription  LowestSalary  \
# 0  <p>Our client is based in Yarraville&nbsp;and ...            50
# 1  <p>DiUS is an Australian technology consultanc...           120
# 2  <div id="FlashContent" class="videoembed"><ifr...           100
# 3  <div id="FlashContent" class="videoembed"><ifr...             0
# 4  <p><strong>The Company</strong></p> <p>Elastom...            50
# 5  <p style="text-align:center;">Do you want a br...            40
# 6  <p>Powerlink, and its predecessor companies ha...           150
# 7  <p><strong>About the company</strong></p>\n   ...            30
# 8  <p><strong>About the Role</strong></p>\n      ...            40
# 9  <p>Our client is a large and established organ...           200
#
#    HighestSalary        JobType
# 0             60  Contract/Temp
# 1            150      Full Time
# 2            120      Full Time
# 3             30      Part Time
# 4             60      Full Time
# 5             50      Full Time
# 6            200  Contract/Temp
# 7             40      Full Time
# 8             50      Full Time
# 9            999      Full Time

# %%
df['Date'] = df['Date'].astype('datetime64[ns]')
df.head(10)
# Out:
#                                                   Id  \
# 0                                           37515643
# 1                                           38154814
# 2                                           37999957
# 3  37936799&searchrequesttoken=57f67ab1-3cfd-4254...
# 4                                           37680645
# 5                                           38063057
# 6                                           38079997
# 7                                           38068325
# 8                                           37409088
# 9                                           37449308
#
#                                                Title  \
# 0  Forklift Drivers WANTED! ***FULL TIME OPPORTUN...
# 1                    Delivery Lead/Iteration Manager
# 2  Local Manager. Permanent, Full time - Lower Hu...
# 3            Clinical Nurse Educator - Youth Justice
# 4                          Graduate Project Engineer
# 5                                       Receptionist
# 6             Principal Engineer Operations Planning
# 7           Forklift Operator with Admin Experience
# 8    Retail Goods Receiving / Warehouse - Springwood
# 9         Commercial Manager - Oil & Gas - PNG based
#
#                                    Company       Date   Location  \
# 0           Australian Personnel Solutions 2018-10-19  Melbourne
# 1                   DIUS Computing Pty Ltd 2019-01-20        NaN
# 2                    Life Without Barriers 2019-01-02        NaN
# 3                 Correct Care Australasia 2018-12-14  Melbourne
# 4                                      NaN 2018-11-09  Melbourne
# 5  Gough Property & Real Estate Recruiters 2019-01-09        NaN
# 6                                Powerlink 2019-01-10        NaN
# 7                                     Toll 2019-01-10        NaN
# 8              Total Tools - Store Network 2018-10-08   Brisbane
# 9                                    Amida 2018-10-12   Brisbane
#
#                        Area                        Classification  \
# 0           Western Suburbs  Manufacturing, Transport & Logistics
# 1                       NaN                                   NaN
# 2                       NaN                                   NaN
# 3       CBD & Inner Suburbs                  Healthcare & Medical
# 4           Western Suburbs                           Engineering
# 5                       NaN                                   NaN
# 6                       NaN                                   NaN
# 7                       NaN                                   NaN
# 8  Southern Suburbs & Logan            Retail & Consumer Products
# 9                       NaN            Mining, Resources & Energy
#
#                                  SubClassification  \
# 0              Warehousing, Storage & Distribution
# 1                                              NaN
# 2                                              NaN
# 3  Nursing - Psych, Forensic & Correctional Health
# 4                              Project Engineering
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                            Other
# 9                                       Management
#
#                                          Requirement  \
# 0  Our client is looking for an experienced count...
# 1  If you love all things Agile and have experien...
# 2  Join our Lower Hunter team as a Local Manager ...
# 3  This is an exciting opportunity for a Clinical...
# 4  Elastomers Australia are currently seeking a G...
# 5  ** Entry Level Real Estate Reception roles SYD...
# 6  Critical expert role to keep Queensland's HV t...
# 7  Immediate start / Morning shift available / Ex...
# 8  Utilise your goods receiving experience and wa...
# 9  Exciting opportunity to work with a reputable ...
#
#                                      FullDescription  LowestSalary  \
# 0  <p>Our client is based in Yarraville&nbsp;and ...            50
# 1  <p>DiUS is an Australian technology consultanc...           120
# 2  <div id="FlashContent" class="videoembed"><ifr...           100
# 3  <div id="FlashContent" class="videoembed"><ifr...             0
# 4  <p><strong>The Company</strong></p> <p>Elastom...            50
# 5  <p style="text-align:center;">Do you want a br...            40
# 6  <p>Powerlink, and its predecessor companies ha...           150
# 7  <p><strong>About the company</strong></p>\n   ...            30
# 8  <p><strong>About the Role</strong></p>\n      ...            40
# 9  <p>Our client is a large and established organ...           200
#
#    HighestSalary        JobType
# 0             60  Contract/Temp
# 1            150      Full Time
# 2            120      Full Time
# 3             30      Part Time
# 4             60      Full Time
# 5             50      Full Time
# 6            200  Contract/Temp
# 7             40      Full Time
# 8             50      Full Time
# 9            999      Full Time

# %%
df['Id'] = df['Id'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df['Id'] = df['Id'].astype('int64')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1154, in astype_nansafe(arr, dtype, copy, skipna)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
# -> 1154         return lib.astype_intsafe(arr, dtype)
#    1156     # if we have a datetime/timedelta array of objects
#    1157     # then coerce to a proper dtype and recall astype_nansafe
#    1159     elif is_datetime64_dtype(dtype):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:668, in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '37936799&searchrequesttoken=57f67ab1-3cfd-4254-92f5-47028699aadd'

# %%
tf = df['Id']
for e,x in enumerate(tf):
    if len(x) > 8:
        tf[e] = x[:8]
df['Id'] = df['Id'].astype('int64')
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_4808\2600484877.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tf[e] = x[:8]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9952 entries, 0 to 9951
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 9952 non-null   int64
#  1   Title              9952 non-null   object
#  2   Company            9576 non-null   object
#  3   Date               9952 non-null   datetime64[ns]
#  4   Location           6204 non-null   object
#  5   Area               3894 non-null   object
#  6   Classification     6204 non-null   object
#  7   SubClassification  6204 non-null   object
#  8   Requirement        9952 non-null   object
#  9   FullDescription    9420 non-null   object
#  10  LowestSalary       9952 non-null   int64
#  11  HighestSalary      9952 non-null   int64
#  12  JobType            9421 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 1010.9+ KB

# %%
df[df['LowestSalary'] > df['HighestSalary']].shape[0]
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Company, Date, Location, Area, Classification, SubClassification, Requirement, FullDescription, LowestSalary, HighestSalary, JobType]
# Index: []

# %%
df.drop_duplicates()
# Out:
#             Id                                              Title  \
# 0     37515643  Forklift Drivers WANTED! ***FULL TIME OPPORTUN...
# 1     38154814                    Delivery Lead/Iteration Manager
# 2     37999957  Local Manager. Permanent, Full time - Lower Hu...
# 3     37936799            Clinical Nurse Educator - Youth Justice
# 4     37680645                          Graduate Project Engineer
# ...        ...                                                ...
# 9947  37996752             Motor Mechanic / Automotive Technician
# 9948  37928224                                   Auto Electrician
# 9949  37587496                                    DA/VIZ Operator
# 9950  38012389                          Quality Assurance Officer
# 9951  37586320                  Workplace Health & Safety Advisor
#
#                                  Company       Date     Location  \
# 0         Australian Personnel Solutions 2018-10-19    Melbourne
# 1                 DIUS Computing Pty Ltd 2019-01-20          NaN
# 2                  Life Without Barriers 2019-01-02          NaN
# 3               Correct Care Australasia 2018-12-14    Melbourne
# 4                                    NaN 2018-11-09    Melbourne
# ...                                  ...        ...          ...
# 9947  FLB Automotive Recruitment Pty Ltd 2018-12-31          NaN
# 9948        Programmed Skilled Workforce 2018-12-13        Perth
# 9949            Seven West Media Limited 2018-10-30       Sydney
# 9950               Real Pet Food Company 2019-01-03          NaN
# 9951                  Sharpe Engineering 2018-10-29  Western QLD
#
#                                    Area                        Classification  \
# 0                       Western Suburbs  Manufacturing, Transport & Logistics
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                   CBD & Inner Suburbs                  Healthcare & Medical
# 4                       Western Suburbs                           Engineering
# ...                                 ...                                   ...
# 9947                                NaN                                   NaN
# 9948                    Eastern Suburbs            Mining, Resources & Energy
# 9949  CBD, Inner West & Eastern Suburbs             Advertising, Arts & Media
# 9950                                NaN                                   NaN
# 9951                                NaN            Mining, Resources & Energy
#
#                                     SubClassification  \
# 0                 Warehousing, Storage & Distribution
# 1                                                 NaN
# 2                                                 NaN
# 3     Nursing - Psych, Forensic & Correctional Health
# 4                                 Project Engineering
# ...                                               ...
# 9947                                              NaN
# 9948               Mining - Engineering & Maintenance
# 9949                         Programming & Production
# 9950                                              NaN
# 9951                     Health, Safety & Environment
#
#                                             Requirement  \
# 0     Our client is looking for an experienced count...
# 1     If you love all things Agile and have experien...
# 2     Join our Lower Hunter team as a Local Manager ...
# 3     This is an exciting opportunity for a Clinical...
# 4     Elastomers Australia are currently seeking a G...
# ...                                                 ...
# 9947  Fantastic opportunity for an experienced motor...
# 9948  Are you looking for an opportunity in Perth af...
# 9949  This position is varied and will perform the d...
# 9950  Awesome opportunity for a passionate and exper...
# 9951  Workplace Health & Safety Advisor required for...
#
#                                         FullDescription  LowestSalary  \
# 0     <p>Our client is based in Yarraville&nbsp;and ...            50
# 1     <p>DiUS is an Australian technology consultanc...           120
# 2     <div id="FlashContent" class="videoembed"><ifr...           100
# 3     <div id="FlashContent" class="videoembed"><ifr...             0
# 4     <p><strong>The Company</strong></p> <p>Elastom...            50
# ...                                                 ...           ...
# 9947  <p>We have a fantastic opportunity for an expe...             0
# 9948  <p><strong>Programmed Skilled Workforce</stron...           120
# 9949  <div id="FlashContent" class="videoembed"><ifr...            70
# 9950  <p><strong>About the company:</strong></p>\n  ...            50
# 9951  <p><strong>Established for 22 years, Sharpe En...            70
#
#       HighestSalary        JobType
# 0                60  Contract/Temp
# 1               150      Full Time
# 2               120      Full Time
# 3                30      Part Time
# 4                60      Full Time
# ...             ...            ...
# 9947             30      Full Time
# 9948            150      Full Time
# 9949             80      Full Time
# 9950             60      Full Time
# 9951             80      Full Time
#
# [9952 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Id                      0
# Title                   0
# Company               376
# Date                    0
# Location             3748
# Area                 6058
# Classification       3748
# SubClassification    3748
# Requirement             0
# FullDescription       532
# LowestSalary            0
# HighestSalary           0
# JobType               531
# dtype: int64

# %%
df.describe()
# Out:
#                  Id  LowestSalary  HighestSalary
# count  9.952000e+03   9952.000000    9952.000000
# mean   3.779744e+07     65.574759     115.072347
# std    2.934618e+05     50.966453     180.476991
# min    3.684559e+07      0.000000      30.000000
# 25%    3.751094e+07     30.000000      40.000000
# 50%    3.788894e+07     60.000000      70.000000
# 75%    3.801222e+07    100.000000     120.000000
# max    3.856223e+07    200.000000     999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9952 entries, 0 to 9951
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 9952 non-null   int64
#  1   Title              9952 non-null   object
#  2   Company            9576 non-null   object
#  3   Date               9952 non-null   datetime64[ns]
#  4   Location           6204 non-null   object
#  5   Area               3894 non-null   object
#  6   Classification     6204 non-null   object
#  7   SubClassification  6204 non-null   object
#  8   Requirement        9952 non-null   object
#  9   FullDescription    9420 non-null   object
#  10  LowestSalary       9952 non-null   int64
#  11  HighestSalary      9952 non-null   int64
#  12  JobType            9421 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 1010.9+ KB

# %%
df.fillna("Other", inplace = True)
df.isnull().sum()
# Out:
# Id                   0
# Title                0
# Company              0
# Date                 0
# Location             0
# Area                 0
# Classification       0
# SubClassification    0
# Requirement          0
# FullDescription      0
# LowestSalary         0
# HighestSalary        0
# JobType              0
# dtype: int64

# %%
df.head()
# Out:
#          Id                                              Title  \
# 0  37515643  Forklift Drivers WANTED! ***FULL TIME OPPORTUN...
# 1  38154814                    Delivery Lead/Iteration Manager
# 2  37999957  Local Manager. Permanent, Full time - Lower Hu...
# 3  37936799            Clinical Nurse Educator - Youth Justice
# 4  37680645                          Graduate Project Engineer
#
#                           Company       Date   Location                 Area  \
# 0  Australian Personnel Solutions 2018-10-19  Melbourne      Western Suburbs
# 1          DIUS Computing Pty Ltd 2019-01-20      Other                Other
# 2           Life Without Barriers 2019-01-02      Other                Other
# 3        Correct Care Australasia 2018-12-14  Melbourne  CBD & Inner Suburbs
# 4                           Other 2018-11-09  Melbourne      Western Suburbs
#
#                          Classification  \
# 0  Manufacturing, Transport & Logistics
# 1                                 Other
# 2                                 Other
# 3                  Healthcare & Medical
# 4                           Engineering
#
#                                  SubClassification  \
# 0              Warehousing, Storage & Distribution
# 1                                            Other
# 2                                            Other
# 3  Nursing - Psych, Forensic & Correctional Health
# 4                              Project Engineering
#
#                                          Requirement  \
# 0  Our client is looking for an experienced count...
# 1  If you love all things Agile and have experien...
# 2  Join our Lower Hunter team as a Local Manager ...
# 3  This is an exciting opportunity for a Clinical...
# 4  Elastomers Australia are currently seeking a G...
#
#                                      FullDescription  LowestSalary  \
# 0  <p>Our client is based in Yarraville&nbsp;and ...            50
# 1  <p>DiUS is an Australian technology consultanc...           120
# 2  <div id="FlashContent" class="videoembed"><ifr...           100
# 3  <div id="FlashContent" class="videoembed"><ifr...             0
# 4  <p><strong>The Company</strong></p> <p>Elastom...            50
#
#    HighestSalary        JobType
# 0             60  Contract/Temp
# 1            150      Full Time
# 2            120      Full Time
# 3             30      Part Time
# 4             60      Full Time

# %%
df['FullDescription'][195]
# Out:
# '<p>The Division of Enterprise has the responsibility of Knowledge Exchange for Social Progress n Economic Prosperity, delivering from Research Excellence, as part of the University’s 2025 Strategy.</p>\n        <p>The Division will significantly increase the University’s knowledge exchange revenue over the next five years through broad partnership with research organisations, industry and government and help transform Australia\'s economic base.&nbsp;</p>\n        <p><strong>About the role</strong></p>\n        <p>The Business Development Manager will focus on identifying new partners and opportunities for UNSW technologies, R&amp;D, innovation and broader capability. &nbsp;They will leverage UNSW technologies and capability to build relationships with\n          external partners including industry, government and communities to generate revenue across all knowledge exchange channels. These include research partnerships (contract and collaborative) and IP commercialisation, as well as consulting and\n          continuing education.&nbsp; As an expert in one or more of Physical Sciences/Engineering/Manufacturing/Mining sectors, the Business Development Manager will operate as the key person between the University and external partners and will drive\n          complex negotiations to ensure we achieve our ambitious 2025 strategy and revenue goals.&nbsp;</p>\n        <p><strong>About you</strong></p>\n        <p>Your relationship and stakeholder management skills coupled with your ability to execute strategy on time and generate significant revenue will complement our team to achieve our 2025 strategy. Specific requirements include:</p>\n        <ul>\n          <li>Relevant Tertiary qualifications (preferably post-graduate)</li>\n          <li>Significant relevant experience in one or more of Physical Sciences/Engineering/Manufacturing/ Mining industry sectors as aligned with University’s research strategy</li>\n          <li>Proactive and motivated with a demonstrated ability to generate commercially beneficial networks and channels</li>\n          <li>Outstanding track record of achievement in closing business deals including research partnerships (contract, collaborative, consulting) and IP commercialisation (licences, spinouts/start-ups, Intellectual Property).</li>\n          <li>Demonstrated ability to deliver training and capability development to a research and/or academic community</li>\n          <li>Strong ability to influence senior management and stakeholders and build long lasting relationships</li>\n          <li>Superior analytical and problem-solving skills, with the ability to use sound judgment in resolving issues as they arise</li>\n          <li>Demonstrated experience developing commercial deals, partnerships and IP agreements</li>\n        </ul>\n        <p><strong>To Apply</strong>: &nbsp;Please submit your resume and cover letter (addressing the selection criteria).</p>\n        <p><strong>Applications close: </strong>Monday 29 October 2018 at 10 am.</p>\n        <p><strong>Contact</strong></p>\n        <p>Shiree Thomas</p>\n        <p>Talent Acquisition Consultant</p>\n        <p>e: <a href="mailto:shiree.thomas@unsw.edu.au" target="_blank">shiree.thomas@unsw.edu.au</a></p>\n        <p>t: <a class="_2hhDNI-" data-contact-match="true" href="tel:02 9385 2401">02 9385 2401</a></p>\n        <p>UNSW aspires to be the exemplar Australian university and employer of choice for people from diverse backgrounds. UNSW aims to ensure equality in recruitment, development, retention and promotion of staff, and that no-one is disadvantaged on the\n          basis of their gender, cultural background, disability, sexual orientation or identity. We encourage everyone who meets the selection criteria to apply.</p>\n        <p>&nbsp;</p>\n        <p>&nbsp;</p>\n        <p>&nbsp;</p>'

# %%
def removeformatting(text):
    formats = []
    new = [0,0]
    result = text
    for e,x in enumerate(text):
        if x == '<':
            new[0] = e
        elif x == '>':
            new[1] = e
            formats.append(tuple(new))
        elif x == "\n":
            formats.append((e,e+1))
    
    for x in formats[::-1]:
        result = result[:x[0]]+result[x[1]+1:]
    return result

removeformatting(df['FullDescription'][195])
# Out:
# The Division of Enterprise has the responsibility of Knowledge Exchange for Social Progress n Economic Prosperity, delivering from Research Excellence, as part of the University’s 2025 Strategy.       The Division will significantly increase the University’s knowledge exchange revenue over the next five years through broad partnership with research organisations, industry and government and help transform Australia's economic base.&nbsp;       About the role       The Business Development Manager will focus on identifying new partners and opportunities for UNSW technologies, R&amp;D, innovation and broader capability. &nbsp;They will leverage UNSW technologies and capability to build relationships with         external partners including industry, government and communities to generate revenue across all knowledge exchange channels. These include research partnerships (contract and collaborative) and IP commercialisation, as well as consulting and         continuing education.&nbsp; As an expert in one or more of Physical Sciences/Engineering/Manufacturing/Mining sectors, the Business Development Manager will operate as the key person between the University and external partners and will drive         complex negotiations to ensure we achieve our ambitious 2025 strategy and revenue goals.&nbsp;       About you       Your relationship and stakeholder management skills coupled with your ability to execute strategy on time and generate significant revenue will complement our team to achieve our 2025 strategy. Specific requirements include:                Relevant Tertiary qualifications (preferably post-graduate)         Significant relevant experience in one or more of Physical Sciences/Engineering/Manufacturing/ Mining industry sectors as aligned with University’s research strategy         Proactive and motivated with a demonstrated ability to generate commercially beneficial networks and channels         Outstanding track record of achievement in closing business deals including research partnerships (contract, collaborative, consulting) and IP commercialisation (licences, spinouts/start-ups, Intellectual Property).         Demonstrated ability to deliver training and capability development to a research and/or academic community         Strong ability to influence senior management and stakeholders and build long lasting relationships         Superior analytical and problem-solving skills, with the ability to use sound judgment in resolving issues as they arise         Demonstrated experience developing commercial deals, partnerships and IP agreements              To Apply: &nbsp;Please submit your resume and cover letter (addressing the selection criteria).       Applications close: Monday 29 October 2018 at 10 am.       Contact       Shiree Thomas       Talent Acquisition Consultant       e: shiree.thomas@unsw.edu.au       t: 02 9385 2401       UNSW aspires to be the exemplar Australian university and employer of choice for people from diverse backgrounds. UNSW aims to ensure equality in recruitment, development, retention and promotion of staff, and that no-one is disadvantaged on the         basis of their gender, cultural background, disability, sexual orientation or identity. We encourage everyone who meets the selection criteria to apply.       &nbsp;       &nbsp;       &nbsp;

# %%
tf = df['FullDescription']
for e,x in enumerate(tf):
    tf[e] = removeformatting(x)
df['FullDescription'][195]
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_4808\3110567988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tf[e] = removeformatting(x)
# "The Division of Enterprise has the responsibility of Knowledge Exchange for Social Progress n Economic Prosperity, delivering from Research Excellence, as part of the University’s 2025 Strategy.       The Division will significantly increase the University’s knowledge exchange revenue over the next five years through broad partnership with research organisations, industry and government and help transform Australia's economic base.&nbsp;       About the role       The Business Development Manager will focus on identifying new partners and opportunities for UNSW technologies, R&amp;D, innovation and broader capability. &nbsp;They will leverage UNSW technologies and capability to build relationships with         external partners including industry, government and communities to generate revenue across all knowledge exchange channels. These include research partnerships (contract and collaborative) and IP commercialisation, as well as consulting and         continuing education.&nbsp; As an expert in one or more of Physical Sciences/Engineering/Manufacturing/Mining sectors, the Business Development Manager will operate as the key person between the University and external partners and will drive         complex negotiations to ensure we achieve our ambitious 2025 strategy and revenue goals.&nbsp;       About you       Your relationship and stakeholder management skills coupled with your ability to execute strategy on time and generate significant revenue will complement our team to achieve our 2025 strategy. Specific requirements include:                Relevant Tertiary qualifications (preferably post-graduate)         Significant relevant experience in one or more of Physical Sciences/Engineering/Manufacturing/ Mining industry sectors as aligned with University’s research strategy         Proactive and motivated with a demonstrated ability to generate commercially beneficial networks and channels         Outstanding track record of achievement in closing business deals including research partnerships (contract, collaborative, consulting) and IP commercialisation (licences, spinouts/start-ups, Intellectual Property).         Demonstrated ability to deliver training and capability development to a research and/or academic community         Strong ability to influence senior management and stakeholders and build long lasting relationships         Superior analytical and problem-solving skills, with the ability to use sound judgment in resolving issues as they arise         Demonstrated experience developing commercial deals, partnerships and IP agreements              To Apply: &nbsp;Please submit your resume and cover letter (addressing the selection criteria).       Applications close: Monday 29 October 2018 at 10 am.       Contact       Shiree Thomas       Talent Acquisition Consultant       e: shiree.thomas@unsw.edu.au       t: 02 9385 2401       UNSW aspires to be the exemplar Australian university and employer of choice for people from diverse backgrounds. UNSW aims to ensure equality in recruitment, development, retention and promotion of staff, and that no-one is disadvantaged on the         basis of their gender, cultural background, disability, sexual orientation or identity. We encourage everyone who meets the selection criteria to apply.       &nbsp;       &nbsp;       &nbsp;"

# %%
tf = df['FullDescription']
tokens = []
for e,s in enumerate(tf):
    token = nltk.word_tokenize(s)
    s = s.translate(str.maketrans('', '', string.punctuation))
    token = nltk.word_tokenize(s)
    token = [x for x in token if x not in nltk.corpus.stopwords.words('english')]
    lemma = nltk.stem.WordNetLemmatizer()
    token = [lemma.lemmatize(x) for x in token]
    tokens.append(token)
df['FullDescription'] = tokens
df['FullDescription'][195]
# Out:
# ['The',
#  'Division',
#  'Enterprise',
#  'responsibility',
#  'Knowledge',
#  'Exchange',
#  'Social',
#  'Progress',
#  'n',
#  'Economic',
#  'Prosperity',
#  'delivering',
#  'Research',
#  'Excellence',
#  'part',
#  'University',
#  '’',
#  '2025',
#  'Strategy',
#  'The',
#  'Division',
#  'significantly',
#  'increase',
#  'University',
#  '’',
#  'knowledge',
#  'exchange',
#  'revenue',
#  'next',
#  'five',
#  'year',
#  'broad',
#  'partnership',
#  'research',
#  'organisation',
#  'industry',
#  'government',
#  'help',
#  'transform',
#  'Australias',
#  'economic',
#  'basenbsp',
#  'About',
#  'role',
#  'The',
#  'Business',
#  'Development',
#  'Manager',
#  'focus',
#  'identifying',
#  'new',
#  'partner',
#  'opportunity',
#  'UNSW',
#  'technology',
#  'RampD',
#  'innovation',
#  'broader',
#  'capability',
#  'nbspThey',
#  'leverage',
#  'UNSW',
#  'technology',
#  'capability',
#  'build',
#  'relationship',
#  'external',
#  'partner',
#  'including',
#  'industry',
#  'government',
#  'community',
#  'generate',
#  'revenue',
#  'across',
#  'knowledge',
#  'exchange',
#  'channel',
#  'These',
#  'include',
#  'research',
#  'partnership',
#  'contract',
#  'collaborative',
#  'IP',
#  'commercialisation',
#  'well',
#  'consulting',
#  'continuing',
#  'educationnbsp',
#  'As',
#  'expert',
#  'one',
#  'Physical',
#  'SciencesEngineeringManufacturingMining',
#  'sector',
#  'Business',
#  'Development',
#  'Manager',
#  'operate',
#  'key',
#  'person',
#  'University',
#  'external',
#  'partner',
#  'drive',
#  'complex',
#  'negotiation',
#  'ensure',
#  'achieve',
#  'ambitious',
#  '2025',
#  'strategy',
#  'revenue',
#  'goalsnbsp',
#  'About',
#  'Your',
#  'relationship',
#  'stakeholder',
#  'management',
#  'skill',
#  'coupled',
#  'ability',
#  'execute',
#  'strategy',
#  'time',
#  'generate',
#  'significant',
#  'revenue',
#  'complement',
#  'team',
#  'achieve',
#  '2025',
#  'strategy',
#  'Specific',
#  'requirement',
#  'include',
#  'Relevant',
#  'Tertiary',
#  'qualification',
#  'preferably',
#  'postgraduate',
#  'Significant',
#  'relevant',
#  'experience',
#  'one',
#  'Physical',
#  'SciencesEngineeringManufacturing',
#  'Mining',
#  'industry',
#  'sector',
#  'aligned',
#  'University',
#  '’',
#  'research',
#  'strategy',
#  'Proactive',
#  'motivated',
#  'demonstrated',
#  'ability',
#  'generate',
#  'commercially',
#  'beneficial',
#  'network',
#  'channel',
#  'Outstanding',
#  'track',
#  'record',
#  'achievement',
#  'closing',
#  'business',
#  'deal',
#  'including',
#  'research',
#  'partnership',
#  'contract',
#  'collaborative',
#  'consulting',
#  'IP',
#  'commercialisation',
#  'licence',
#  'spinoutsstartups',
#  'Intellectual',
#  'Property',
#  'Demonstrated',
#  'ability',
#  'deliver',
#  'training',
#  'capability',
#  'development',
#  'research',
#  'andor',
#  'academic',
#  'community',
#  'Strong',
#  'ability',
#  'influence',
#  'senior',
#  'management',
#  'stakeholder',
#  'build',
#  'long',
#  'lasting',
#  'relationship',
#  'Superior',
#  'analytical',
#  'problemsolving',
#  'skill',
#  'ability',
#  'use',
#  'sound',
#  'judgment',
#  'resolving',
#  'issue',
#  'arise',
#  'Demonstrated',
#  'experience',
#  'developing',
#  'commercial',
#  'deal',
#  'partnership',
#  'IP',
#  'agreement',
#  'To',
#  'Apply',
#  'nbspPlease',
#  'submit',
#  'resume',
#  'cover',
#  'letter',
#  'addressing',
#  'selection',
#  'criterion',
#  'Applications',
#  'close',
#  'Monday',
#  '29',
#  'October',
#  '2018',
#  '10',
#  'Contact',
#  'Shiree',
#  'Thomas',
#  'Talent',
#  'Acquisition',
#  'Consultant',
#  'e',
#  'shireethomasunsweduau',
#  '02',
#  '9385',
#  '2401',
#  'UNSW',
#  'aspires',
#  'exemplar',
#  'Australian',
#  'university',
#  'employer',
#  'choice',
#  'people',
#  'diverse',
#  'background',
#  'UNSW',
#  'aim',
#  'ensure',
#  'equality',
#  'recruitment',
#  'development',
#  'retention',
#  'promotion',
#  'staff',
#  'noone',
#  'disadvantaged',
#  'basis',
#  'gender',
#  'cultural',
#  'background',
#  'disability',
#  'sexual',
#  'orientation',
#  'identity',
#  'We',
#  'encourage',
#  'everyone',
#  'meet',
#  'selection',
#  'criterion',
#  'apply',
#  'nbsp',
#  'nbsp',
#  'nbsp']

# %%
df.to_csv('preprocessed.csv',index=False)

# %%
print(len(df["Title"].unique()))
print(len(df["Company"].unique()))
print(df["Location"].unique())
print(df["Area"].unique())
print(df["Classification"].unique())
print(df["SubClassification"].unique())
print(df["JobType"].unique())
# Out:
# 8411
# 4536
# ['Melbourne' 'Other' 'Brisbane' 'Wollongong, Illawarra & South Coast'
#  'Perth' 'Sydney' 'ACT' 'Newcastle, Maitland & Hunter'
#  'Bendigo, Goldfields & Macedon Ranges' 'Blue Mountains & Central West'
#  'Southern Highlands & Tablelands' 'Port Hedland, Karratha & Pilbara'
#  'Launceston & North East' 'Horsham & Grampians'
#  'Coober Pedy & Outback SA' 'Adelaide' 'Northern QLD'
#  'Bairnsdale & Gippsland' 'Rockhampton & Capricorn Coast' 'Gold Coast'
#  'Mackay & Coalfields' 'Bundaberg & Wide Bay Burnett'
#  'Gosford & Central Coast' 'Darwin' 'Bunbury & South West'
#  'Cairns & Far North' 'Whyalla & Eyre Peninsula' 'Hobart'
#  'South West Coast VIC' 'Yarra Valley & High Country'
#  'Katherine & Northern Australia' 'Sunshine Coast'
#  'Port Macquarie & Mid North Coast' 'Mildura & Murray'
#  'West Gippsland & Latrobe Valley' 'Ballarat & Central Highlands'
#  'Adelaide Hills & Barossa' 'Dubbo & Central NSW'
#  'Geraldton, Gascoyne & Midwest' 'Gladstone & Central QLD'
#  'Mt Gambier & Limestone Coast' 'Shepparton & Goulburn Valley'
#  'Wagga Wagga & Riverina' 'Devonport & North West'
#  'Toowoomba & Darling Downs' 'Kalgoorlie, Goldfields & Esperance'
#  'Lismore & Far North Coast' 'Richmond & Hawkesbury' 'Western QLD'
#  'Coffs Harbour & North Coast' 'Albury Area'
#  'Alice Springs & Central Australia' 'Mornington Peninsula & Bass Coast'
#  'Riverland & Murray Mallee' 'Tamworth & North West NSW'
#  'Far West & North Central NSW' 'Northam & Wheatbelt' 'Broome & Kimberley'
#  'Fleurieu Peninsula & Kangaroo Island' 'Hervey Bay & Fraser Coast'
#  'Albany & Great Southern' 'Somerset & Lockyer'
#  'Yorke Peninsula & Clare Valley' 'Mandurah & Peel'
#  'Central & South East TAS' 'Tumut, Snowy & Monaro']
# ['Western Suburbs' 'Other' 'CBD & Inner Suburbs'
#  'Southern Suburbs & Logan' 'Eastern Suburbs'
#  'North Shore & Northern Beaches' 'CBD, Inner & Western Suburbs'
#  'CBD, Inner West & Eastern Suburbs' 'Northern Suburbs'
#  'Northern Suburbs & Joondalup' 'Parramatta & Western Suburbs'
#  'Bayside & Eastern Suburbs' 'Ryde & Macquarie Park'
#  'North West & Hills District' 'Fremantle & Southern Suburbs'
#  'Bayside & South Eastern Suburbs' 'South West & M5 Corridor'
#  'Western Suburbs & Ipswich' 'Southern Suburbs & Sutherland Shire'
#  'Rockingham & Kwinana']
# ['Manufacturing, Transport & Logistics' 'Other' 'Healthcare & Medical'
#  'Engineering' 'Retail & Consumer Products' 'Mining, Resources & Energy'
#  'Information & Communication Technology' 'Construction'
#  'Trades & Services' 'Legal' 'Education & Training' 'Sales'
#  'Marketing & Communications' 'Hospitality & Tourism' 'Accounting'
#  'Administration & Office Support' 'Banking & Financial Services'
#  'Community Services & Development' 'Government & Defence'
#  'CEO & General Management' 'Real Estate & Property'
#  'Insurance & Superannuation' 'Human Resources & Recruitment'
#  'Call Centre & Customer Service' 'Consulting & Strategy'
#  'Design & Architecture' 'Advertising, Arts & Media' 'Sport & Recreation'
#  'Farming, Animals & Conservation' 'Science & Technology'
#  'Self Employment']
# ['Warehousing, Storage & Distribution' 'Other'
#  'Nursing - Psych, Forensic & Correctional Health' 'Project Engineering'
#  'Management' 'Mechanical Engineering'
#  'Mining - Engineering & Maintenance' 'Retail Assistants'
#  'Civil/Structural Engineering' 'Pharmaceuticals & Medical Devices'
#  'Engineering - Software' 'Welders & Boilermakers'
#  'Corporate & Commercial Law' 'Teaching - Early Childhood'
#  'Analysis & Reporting' 'New Business Development'
#  'Marketing Assistants/Coordinators' 'Programme & Project Management'
#  'Market Research & Analysis' 'Generalists - In-house'
#  'Generalists - Law Firm' 'Bar & Beverage Staff' 'Medical Specialists'
#  'Bookkeeping & Small Practice Accounting'
#  'Records Management & Document Control' 'Management - Schools'
#  'Waiting Staff' 'Physiotherapy, OT & Rehabilitation'
#  'Teaching - Vocational' 'Nursing - Aged Care' 'Cleaning Services'
#  'Law Clerks & Paralegals' 'Management - Store'
#  'Health, Safety & Environment' 'Banking - Business'
#  'Sales Representatives/Consultants' 'Aged & Disability Support'
#  'Plant & Machinery Operators' 'Business/Systems Analysts'
#  'Government - State' 'Management Accounting & Budgeting'
#  'Mining - Drill & Blast' 'Couriers, Drivers & Postal Services' 'Pharmacy'
#  'Security' 'CEO' 'Developers/Programmers' 'Residential Sales'
#  'Telecommunications' 'Direct Marketing & CRM' 'Government - Local'
#  'Account & Relationship Management' 'Project Management'
#  'General Practitioners' 'Chefs/Cooks' 'Teaching - Primary'
#  'Maintenance & Handyperson Services' 'Hair & Beauty Services' 'Claims'
#  'Fitters, Turners & Machinists' 'Accounts Receivable/Credit Control'
#  'Recruitment - Agency' 'Automotive Trades' 'Architects' 'Electricians'
#  'Research & Fellowships' 'Nursing - General Medical & Surgical'
#  'Funds Management' 'Medical Administration'
#  'Air Conditioning & Refrigeration' 'Government - Federal'
#  'Building Services Engineering' 'Oil & Gas - Engineering & Maintenance'
#  'Customer Service - Call Centre' 'Sales' 'Front Office & Guest Services'
#  'Event Management' 'Medical Imaging' 'Accounts Officers/Clerks'
#  'Administrative Assistants' 'Residents & Registrars'
#  'Foreperson/Supervisors' 'Labourers' 'Dental' 'Butchers'
#  'Engineering - Network' 'Community Development' 'Receptionists'
#  'Strategy & Planning' 'Management - Department/Assistant'
#  'Nursing - A&E, Critical Care & ICU' 'Legal Secretaries' 'Graphic Design'
#  'Pickers & Packers' 'Contracts Management'
#  'Database Development & Administration' 'Compliance & Risk'
#  'Sales - Pre & Post' 'Web & Interaction Design'
#  'Testing & Quality Assurance' 'Residential Leasing & Property Management'
#  'Security Services' 'Travel Agents/Consultants'
#  'Agency Account Management' 'Web Development & Production'
#  'Electrical/Electronic Engineering' 'Plumbers'
#  'Production, Planning & Scheduling' 'Payroll' 'Road Transport'
#  'Programming & Production' 'Analysts' 'Kitchen & Sandwich Hands'
#  'Taxation' 'Sales - Outbound' 'Client & Sales Administration'
#  'Recruitment - Internal' 'Brokerage' 'Clinical/Medical Research'
#  'Accounts Payable' 'Financial Accounting & Reporting'
#  'Freight/Cargo Forwarding' 'Brand Management' 'Architecture'
#  'Networks & Systems Administration' 'Client Services' 'Superannuation'
#  'Body Corporate & Facilities Management' 'Corporate Development'
#  'Estimating' 'Sales - Inbound' "Workers' Compensation"
#  'Public Relations & Corporate Affairs' 'Help Desk & IT Support'
#  'General/Business Unit Manager' 'Technicians'
#  'Financial Managers & Controllers' 'Housekeeping'
#  'Banking - Retail/Branch' 'Valuation' 'Management & Change Consulting'
#  'Insurance & Superannuation Law' 'Business Services & Corporate Advisory'
#  'Nursing - Theatre & Recovery' 'Industrial Relations & Employment Law'
#  'Audit - External' 'Consultants' 'Audit - Internal'
#  'Assembly & Process Work' 'Power Generation & Distribution'
#  'Litigation & Dispute Resolution' 'Teaching - Secondary'
#  'Nursing - Management' 'Art Direction' 'Environmental Engineering'
#  'Engineering - Hardware' 'Data Entry & Word Processing'
#  'Childcare & Outside School Hours Care' 'Assistant Accountants'
#  'Quality Assurance & Control' 'Banking & Finance Law'
#  'Purchasing, Procurement & Inventory' 'Retail & Property Development'
#  'Aerospace Engineering' 'Automotive Engineering' 'Building Trades'
#  'Management & Support' 'Housing & Homelessness Services'
#  'Marketing Communications' 'Fundraising' 'Digital & Search Marketing'
#  'Mining - Operations' 'Machine Operators' 'Fitness & Personal Training'
#  'Contracts Administration' 'PA, EA & Secretarial'
#  'Carpentry & Cabinet Making' 'Financial Planning' 'Credit'
#  'Mining - Exploration & Geoscience' 'Office Management'
#  'Occupational Health & Safety' 'Fashion & Textile Design'
#  'Consulting & Generalist HR' 'Supervisors/Team Leaders' 'Administration'
#  'Oil & Gas - Operations' 'Fishing & Aquaculture' 'Pathology'
#  'Speech Therapy' 'Merchandisers' 'Gardening & Landscaping'
#  'Management - Area/Multi-site' 'Property Law' 'Employment Services'
#  'Painters & Sign Writers' 'Internal Communications' 'Actuarial'
#  'Cost Accounting' 'Customer Service - Customer Facing'
#  'Chemistry & Physics' 'Corporate Finance & Investment Banking'
#  'Bakers & Pastry Chefs' 'Organisational Development'
#  'Criminal & Civil Law' 'Systems Engineering'
#  'Printing & Publishing Services' 'Journalism & Writing' 'Tax Law'
#  'Farm Labour' 'Product Management & Development' 'Planning & Scheduling'
#  'Training & Development' 'Industrial Engineering'
#  'Architectural Drafting' 'Child Welfare, Youth & Family Services'
#  'Maintenance' 'Mortgages' 'Indigenous & Multicultural Services'
#  'Nursing - Community, Maternal & Child Health' 'Treasury'
#  'Nursing - Educators & Facilitators'
#  'Nursing - Midwifery, Neo-Natal, SCN & NICU' 'Horticulture'
#  'Teaching - Tertiary' 'Library Services & Information Management'
#  'Commercial Sales, Leasing & Property Mgmt' 'Interior Design'
#  'Environmental, Earth & Geosciences'
#  'Environment & Sustainability Consulting' 'Urban Design & Planning'
#  'Psychology, Counselling & Social Work' 'Gaming' 'Student Services'
#  'Family Law' 'Fleet Management' 'Teaching Aides & Special Needs'
#  'Surveying' 'Nursing - High Acuity' 'Aviation Services'
#  'Technical Writing' 'COO & MD' 'Construction Law'
#  'Workplace Training & Assessment' 'Mining - Processing'
#  'Rail & Maritime Transport' 'Tutoring' 'Industrial & Employee Relations'
#  'Personal Injury Law' 'Risk Consulting'
#  'Mathematics, Statistics & Information Sciences' 'Team Leaders'
#  'Assessment' 'Banking - Corporate & Institutional' 'Industrial Design'
#  'Tour Guides' 'Management - Internal' 'Engineering Drafting'
#  'Import/Export & Customs' 'Sales Coordinators' 'Nannies & Babysitters'
#  'Policy, Planning & Regulation' 'Laboratory & Technical Services'
#  'Food Technology & Safety' 'Water & Waste Engineering'
#  'Systems Accounting & IT Audit' 'Reservations' 'Ambulance/Paramedics'
#  'Farm Management' 'Oil & Gas - Drilling' 'Stockbroking & Trading'
#  'Trade Marketing' 'Self Employment' 'Field Engineering'
#  'Emergency Services' 'Government' 'Team Leaders/Supervisors' 'Navy'
#  'Buying' 'Veterinary Services & Animal Welfare' 'Planning' 'Collections'
#  'Environmental Services' 'Management - Universities'
#  'Biological & Biomedical Sciences' 'Underwriting' 'Airlines'
#  'Chiropractic & Osteopathic' 'Agronomy & Farm Services'
#  'Legal Practice Management' 'Insolvency & Corporate Recovery'
#  'Oil & Gas - Exploration & Geoscience' 'Winery & Viticulture'
#  'Natural Resources & Water' 'Chemical Engineering'
#  'Media Strategy, Planning & Buying' 'Nursing - Paediatric & PICU'
#  'Local Government' 'Public Transport & Taxi Services'
#  'Board Appointments' 'Photography' 'Fund Administration' 'Policy'
#  'Coaching & Instruction' 'Editing & Publishing'
#  'Environment & Planning Law' 'Landscape Architecture' 'Performing Arts'
#  'Management - Vocational' 'Optical' 'Conservation, Parks & Wildlife'
#  'Locksmiths' 'Process Engineering' 'Biotechnology & Genetics'
#  'Supervisors']
# ['Contract/Temp' 'Full Time' 'Part Time' 'Casual/Vacation' 'Other']
